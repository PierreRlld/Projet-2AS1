# %%
import pandas as pd
import numpy as np

# %%
# data.csv est le fichier .csv contenant la liste des auteurs. Il y en a 622.
data = pd.read_csv('data.csv',index_col=[0])
data
# Out:
#                        Nom        Mouvement  \
# 0     William S. Burroughs  Beat Generation
# 1              Lucien Carr  Beat Generation
# 2          Carolyn Cassady  Beat Generation
# 3      John Clellon Holmes  Beat Generation
# 4            Gregory Corso  Beat Generation
# ..                     ...              ...
# 617  Jacques_Rabemananjara        Négritude
# 618     Léon-Gontran_Damas        Négritude
# 619           Guy_Tirolien        Négritude
# 620            Birago_Diop        Négritude
# 621          René_Depestre        Négritude
#
#                                                summary  \
# 0    William Seward Burroughs (/ˈwɪljəm ˈsuɚd ˈbɜɹo...
# 1    Lucien Carr, né le 1er mars 1925 à New York et...
# 2    Carolyn Cassady, née Carolyn Robinson le 28 av...
# 3    John Clellon Holmes est un romancier, essayist...
# 4    Gregory Nunzio Corso (New York, 26 mars 1930 -...
# ..                                                 ...
# 617  Jacques Bemananjara dit Rabemananjara est un i...
# 618  Léon-Gontran Damas, né le 28 mars 1912 à Cayen...
# 619  Guy Tirolien, né le 13 février 1917 à Pointe-à...
# 620  Birago Diop (12 décembre 1906 à Ouakam, Dakar,...
# 621  René Depestre est un poète, romancier et essay...
#
#                                                sum_lem  mvm_label
# 0    William Seward Burroughs ˈsuɚd dit William Bur...          0
# 1    Lucien Carr naître premier mars 1925 New York ...          0
# 2    Carolyn Cassady naître Carolyn Robinson 28 avr...          0
# 3    John Clellon holme romancier essayiste poète a...          0
# 4    gregory Nunzio Corso New York 26 mars 1930 Min...          0
# ..                                                 ...        ...
# 617  Jacques Bemananjara dit Rabemananjara intellec...          9
# 618  Léon Gontran Damas naître 28 mars 1912 Cayenne...          9
# 619  Guy Tirolien naître 13 février 1917 Guadeloupe...          9
# 620  Birago Diop 12 décembre 1906 Ouakam Dakar Séné...          9
# 621  René Depestre poète romancier essayiste naître...          9
#
# [622 rows x 5 columns]

# %%
datab = pd.read_csv('Mouvements_wiki_cleaned.csv',index_col=[0])
# Mouvements_wiki_cleaned est le .csv contenant les pages wikipédia des mouvements littéraires.
datab.head()
# Out:
#                          mouvement  \
# 0  Litt%C3%A9rature_hagiographique
# 1                 Chanson_de_geste
# 2                       Troubadour
# 3                   Roman_courtois
# 4                          Fabliau
#
#                                                texte  \
# 0  L’hagiographie (du grec ancien ἅγιος / hágios ...
# 1  La chanson de geste est un genre littéraire eu...
# 2  Un troubadour (de loccitan trobador : « trouve...
# 3  Un roman courtois est un long récit écrit au M...
# 4  Fabliau (du picard, lui-même issu du latin fab...
#
#                                            texte_lem  \
# 0  hagiographie grec ancien ἅγιος hágio saint γρά...
# 1  le chanson geste genre littéraire européen il ...
# 2  un troubadour loccitan trobador trouveur troba...
# 3  un roman courtois long récit écrire moyen âge ...
# 4  Fabliau picard issu latin fabuler donner franç...
#
#                                               tf_idf
# 0  ['hagiographie', 'hagiographique', 'saint', 'h...
# 1  ['geste', 'chanson', 'cycle', 'Vivien', 'Charl...
# 2  ['troubadour', 'occitan', 'trobar', 'arabe', '...
# 3  ['courtois', 'chevalier', 'matière', 'Perceval...
# 4  ['fabliau', 'vilain', 'bourgeoisie', 'clerc', ...

# %%
#juste pour ressortir toutes les prédictions "ex aequo" dans la fonction suivante (explications en return de la fonction suivante)

def sort_ish(L):
    mov,key = L[0]
    sorted_final=[mov]
    k=1
    n=len(L)
    while k<n:
        mov,keyy=L[k]
        if keyy<key:
            return sorted_final
        else:
            sorted_final.append(mov)
            k+=1
    return sorted_final

# %%
#j'ai fixé les arguments sauf name pour pvoir utiliser directement sur le dataframe avec la méthode apply (cf ci dessous)
#c'est évidemment juste pour le premier essai


def pred(name,database=data,train=datab,n=10,option='texte'):
    if option=='tf-idf':
        #avec l'option tf-idf, on se base sur les mots les plus importants pour chaque mouvement au sens 
        #de la métrique tf-idf
        
        txt = database[database['Nom']==name]['sum_lem'].values[0].split()
        #on prend le texte associé à l'auteur *name*
        
        pred={}
        #dictionnaire des prédictions
        
        m=len(train)
        
        for k in range(m):
            #pour chaque mouvement
            
            mov = train['mouvement'][k] #on récupère son nom
            L= eval(train['tf_idf'][k])[:n] #et les n premiers mots tf_idf (n paramètre de la fction)
            c=0 #compteur qui va compter combien de mots du texte associé à l'auteur (le summary wikipedia)
            #sont des mots présents dans les n tf idf
            for keyword in L:
                #pour chaque mot clé tf idf
                if keyword in txt:
                    #s'il est dans le texte associé à l'auteur, on incrémente c.
                    c+=1
            pred[mov]=c 
            #le nombre de mots est associé au mouvement dans le dictionnaire
        PRED = sorted(pred.items(), key=lambda mot_proba: mot_proba[1])      
        PRED.reverse()
        #on ordonne le dictionnaire selon les clés
        return sort_ish(PRED) #on retourne tous les mots ayant la valeur maximale ! 
        # on va en effet obtenir des mots et des scores associés. On va prendre tous les mots atteignant le score maximal car il n'y a pas de moyen de différencier ceux-là.
    
    
    if option=='texte':
        #idem que pour tf-idf sauf qu'on s'intéresse à tout le texte lemmatisé de la page du mouvement 
        txt = database[database['Nom']==name]['sum_lem'].values[0].split()
        pred={}
        m=len(train)
        for k in range(m):
            mov = train['mouvement'][k]
            L= train['texte_lem'][k].split() #voilà la seule différence : 
            #on prend comme liste de mots L le texte_lem qui est le texte de la page wiki du mouvement.
            c=0
            for keyword in L:
                if keyword in txt:
                    c+=1
            pred[mov]=c
        PRED = sorted(pred.items(), key=lambda mot_proba: mot_proba[1])
        PRED.reverse()
        return sort_ish(PRED)

# %%
data['pred_txt']=data['Nom'].apply(pred) #réalisation de la prédiction

# %%
data #exemple sur la première base de données
# Out:
#      Unnamed: 0                   Nom        Mouvement  \
# 0             0  William S. Burroughs  Beat Generation
# 1             1           Lucien Carr  Beat Generation
# 2             2       Carolyn Cassady  Beat Generation
# 3             3   John Clellon Holmes  Beat Generation
# 4             4         Gregory Corso  Beat Generation
# ..          ...                   ...              ...
# 256         256     Maurice Beaubourg       symboliste
# 257         257        Otokar Březina       symboliste
# 258         258   Emanuil Popdimitrov       symboliste
# 259         259         Marcel Schwob       symboliste
# 260         260     Friedebert Tuglas       symboliste
#
#                                                summary  \
# 0    William Seward Burroughs (/ˈwɪljəm ˈsuɚd ˈbɜɹo...
# 1    Lucien Carr, né le 1er mars 1925 à New York et...
# 2    Carolyn Cassady, née Carolyn Robinson le 28 av...
# 3    John Clellon Holmes est un romancier, essayist...
# 4    Gregory Nunzio Corso (New York, 26 mars 1930 -...
# ..                                                 ...
# 256  Maurice Beaubourg, né le 4 décembre 1859 et mo...
# 257  Otokar Březina, né Václav Ignác Jebavý le 13 s...
# 258  Emanuil Popdimitrov Popzahariev est un poète, ...
# 259  Marcel Schwob, né à Chaville (Seine-et-Oise, a...
# 260  Friedebert Tuglas (né Friedebert Mihkelson le ...
#
#                                                sum_lem  mvm_label  \
# 0    William Seward Burroughs ˈsuɚd dit William Bur...          0
# 1    Lucien Carr naître premier mars 1925 New York ...          0
# 2    Carolyn Cassady naître Carolyn Robinson 28 avr...          0
# 3    John Clellon holme romancier essayiste poète a...          0
# 4    gregory Nunzio Corso New York 26 mars 1930 Min...          0
# ..                                                 ...        ...
# 256  Maurice Beaubourg naître 4 décembre 1859 mort ...          9
# 257  otokar Březina naître Václav Ignác jebavý 13 s...          9
# 258  emanuil Popdimitrov Popzahariev poète philosop...          9
# 259  Marcel Schwob naître Chaville 23 août 1867 mor...          9
# 260  Friedebert Tuglas né Friedebert Mihkelson 2 ma...          9
#
#                pred_txt
# 0    [Symbolisme_(art)]
# 1    [Symbolisme_(art)]
# 2     [Beat_Generation]
# 3    [Symbolisme_(art)]
# 4     [Beat_Generation]
# ..                  ...
# 256  [Symbolisme_(art)]
# 257  [Symbolisme_(art)]
# 258  [Symbolisme_(art)]
# 259  [Symbolisme_(art)]
# 260  [Symbolisme_(art)]
#
# [261 rows x 7 columns]
